# %% [markdown]
# <a href="https://colab.research.google.com/github/PiotrMaciejKowalski/BigData2022-actors/blob/profiling_new/colabs/Profiling_NewData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Przygotowanie notatnika

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/PiotrMaciejKowalski/BigData2022-actors.git
# !mv /content/BigData2022-actors/* .
# !mv /content/BigData2022-actors/.* .
# !rmdir /content/BigData2022-actors/
# Out:
# Cloning into 'BigData2022-actors'...
# remote: Enumerating objects: 808, done.
# remote: Counting objects: 100% (314/314), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 808 (delta 201), reused 105 (delta 81), pack-reused 494
# Receiving objects: 100% (808/808), 5.80 MiB | 34.16 MiB/s, done.
# Resolving deltas: 100% (419/419), done.
# mv: cannot move '/content/BigData2022-actors/colabs' to './colabs': Directory not empty
# mv: cannot move '/content/BigData2022-actors/data' to './data': Directory not empty
# mv: cannot move '/content/BigData2022-actors/docs' to './docs': Directory not empty
# mv: cannot move '/content/BigData2022-actors/lib' to './lib': Directory not empty
# mv: cannot move '/content/BigData2022-actors/notebooks' to './notebooks': Directory not empty
# mv: cannot move '/content/BigData2022-actors/tests' to './tests': Directory not empty
# mv: cannot move '/content/BigData2022-actors/tutorials' to './tutorials': Directory not empty
# ...

# %% [markdown]
# ## Załadowanie danych z pliku o rozszerzeniu .parquet

# %%
from lib.const import JOINED_DATA, DATA_WITH_AWARDS

# %% [markdown]
# W poradniku "Tworzenie skrotu do GDrive" w folderze tutorials jest poradnik jak sprawić żeby poniższa lokalizacja się poprawnie ładowała.

# %%
dane = pd.read_parquet(DATA_WITH_AWARDS)
# TODO przepiąć się na nowszy plik gdy będzie on już zapisany na dysku

# %% [markdown]
# # Profiling

# %%
from pandas_profiling import ProfileReport

# %%
raport = ProfileReport(dane)
raport

# %%
report.to_file("Analysis_with_Awards.html")
